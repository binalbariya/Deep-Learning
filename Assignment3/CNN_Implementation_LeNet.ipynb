# %%
#loading modules

import cv2
import numpy as np
import keras
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
from keras.datasets import cifar10
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import confusion_matrix
from keras.layers import Conv2D, MaxPool2D, Flatten, Dense, Dropout,Activation
from keras.models import Sequential, load_model
from keras.callbacks import EarlyStopping

# %%
# load dataset
(X_train, y_train), (X_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 2s 0us/step

# %%
print("Training shape: ",X_train.shape)
print("Testing shape: ",X_test.shape)
print("Output training shape: ",y_train.shape)
print("output testing shape: ",y_test.shape)
# Out:
# Training shape:  (50000, 32, 32, 3)
# Testing shape:  (10000, 32, 32, 3)
# Output training shape:  (50000, 1)
# output testing shape:  (10000, 1)

# %%
labels = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
fig, axes = plt.subplots(ncols=7, nrows=3, figsize=(17, 8))
index = 0
for i in range(3):
    for j in range(7):
        axes[i,j].set_title(labels[y_train[index][0]])
        axes[i,j].imshow(X_train[index])
        axes[i,j].get_xaxis().set_visible(False)
        axes[i,j].get_yaxis().set_visible(False)
        index += 1
plt.show()

# %%
#Convert to grayscale

X_train = np.array([cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) for image in X_train])
X_test = np.array([cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) for image in X_test])

# %%
fig, axes = plt.subplots(ncols=7, nrows=3, figsize=(17, 8))
index = 0
for i in range(3):
    for j in range(7):
        axes[i,j].set_title(labels[y_train[index][0]])
        axes[i,j].imshow(X_train[index], cmap='gray')
        axes[i,j].get_xaxis().set_visible(False)
        axes[i,j].get_yaxis().set_visible(False)
        index += 1
plt.show()

# %%
X_train  = X_train/255
X_test  = X_test/255

# %%
one_hot_encoder = OneHotEncoder(sparse=False)

# %%
one_hot_encoder.fit(y_train)
# Out:
# OneHotEncoder(categories='auto', drop=None, dtype=<class 'numpy.float64'>,
#               handle_unknown='error', sparse=False)

# %%
y_train = one_hot_encoder.transform(y_train)
y_test = one_hot_encoder.transform(y_test)

# %%
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], X_train.shape[2], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2], 1)

# %%
input_shape = (X_train.shape[1], X_train.shape[2], 1)

# %%
input_shape
# Out:
# (32, 32, 1)

# %%
# Create a model and add layers
model = Sequential()

# %% [markdown]
# #1st Convolution layer

# %%
#here input shape is (32,32,1) and output shape is (28,28,6)
#As per the formula output shape is derived as (n-f+2p/s + 1, n-f+2p/s + 1, no. of filters)
# here n refers to input shape i.e n=32
# f refers to filter size which we need to calculate
# no. of filters given in question is 6 
# so 28 = n-f+2*0/s + 1 = 32-f/1 + 1 
#27 = 32-f 
# so f = 32-27 = 5
#so our filter size is (5,5)

model.add(Conv2D(filters = 6, kernel_size = (5,5), activation='relu', strides=(1, 1), input_shape=input_shape))

# %%
#checking the output shape as per our given requirements
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# =================================================================
# Total params: 156
# Trainable params: 156
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #1st Subsampling Layer

# %%
import tensorflow as tf
#here input shape is (28,28,6) and output shape is (14,14,6)
#As per the formula output shape is derived as (n-f+2p/s + 1, n-f+2p/s + 1, no. of filters)
# here n refers to input shape i.e n=28
# f refers to filter size which we need to calculate
# no. of filters given in question is 6
#here stride=2 
# so 14 = n-f+2*0/s + 1 = 28-f/2 + 1 
#13 = 28-f/2 
# so f = 28-26 = 2
#so our filter size is (2,2)
model.add(tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=None))

# %%
#checking the output shape as per our given requirements
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# =================================================================
# Total params: 156
# Trainable params: 156
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #2nd Convolution Layer

# %%
#here input shape is (14,14,6) and output shape is (10,10,16)
#As per the formula output shape is derived as (n-f+1, n-f+1, no. of filters)
# here n refers to input shape i.e n=14
# f refers to filter size which we need to calculate
# no. of filters given in question is 16 
# so 10 = n-f+1 = 14-f+1 = 15-f 
# so f = 15-10 = 5
#so our filter size is (5,5)

model.add(Conv2D(filters = 16, kernel_size = (5,5), activation='relu', strides=(1, 1), input_shape=input_shape))

# %%
#checking the output shape as per our given requirements
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# =================================================================
# Total params: 2,572
# Trainable params: 2,572
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #2nd SubSampling Layer

# %%
import tensorflow as tf
#here input shape is (10,10,16) and output shape is (5,5,16)
#As per the formula output shape is derived as (n-f+2p/s + 1, n-f+2p/s + 1, no. of filters)
# here n refers to input shape i.e n=10
# f refers to filter size which we need to calculate
# no. of filters given in question is 16
#here stride=2 
# so 5 = n-f+2*0/s + 1 = 10-f/2 + 1 
#4 = 10-f/2 
# so f = 10-8 = 2
#so our filter size is (2,2)
model.add(tf.keras.layers.AveragePooling2D(pool_size=(2, 2), strides=None))

# %%
#checking the output shape as per our given requirements
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# =================================================================
# Total params: 2,572
# Trainable params: 2,572
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.add(Flatten())

# %% [markdown]
# #Fully Connected Layer1

# %%
model.add(Dense(120, input_shape=(5,5,16)))
# Add Dropout to prevent overfitting
model.add(Dropout(0.4))

# %%
#checking the output shape as per our given requirements
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dropout (Dropout)            (None, 120)               0
# =================================================================
# Total params: 50,692
# Trainable params: 50,692
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #2nd Fully COnnected Layer

# %%
#2nd Fully Connected Layer
model.add(Dense(84))
#Add Dropout
model.add(Dropout(0.4))

# %%
#checking the output shape as per our given requirements
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dropout (Dropout)            (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 84)                0
# =================================================================
# Total params: 60,856
# Trainable params: 60,856
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Output Layer

# %%
#Output Layer
model.add(Dense(10))
model.add(Activation('softmax'))

# %%
#checking the output shape as per our given requirements
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 28, 28, 6)         156
# _________________________________________________________________
# average_pooling2d (AveragePo (None, 14, 14, 6)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 10, 10, 16)        2416
# _________________________________________________________________
# average_pooling2d_1 (Average (None, 5, 5, 16)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 400)               0
# _________________________________________________________________
# dense (Dense)                (None, 120)               48120
# _________________________________________________________________
# dropout (Dropout)            (None, 120)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                10164
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 84)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                850
# _________________________________________________________________
# activation (Activation)      (None, 10)                0
# =================================================================
# Total params: 61,706
# Trainable params: 61,706
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# #Compile the Model

# %%
model.compile(loss='categorical_crossentropy', 
     optimizer='adam',
     metrics=['acc'])

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=3)

# %%
history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_test, y_test), callbacks=[es])
# Out:
# Epoch 1/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.9963 - acc: 0.2709 - val_loss: 1.5923 - val_acc: 0.4252
# Epoch 2/20
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.6281 - acc: 0.4170 - val_loss: 1.5017 - val_acc: 0.4627
# Epoch 3/20
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.4982 - acc: 0.4721 - val_loss: 1.4285 - val_acc: 0.4974
# Epoch 4/20
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.4569 - acc: 0.4901 - val_loss: 1.4064 - val_acc: 0.5080
# Epoch 5/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.4105 - acc: 0.5053 - val_loss: 1.3600 - val_acc: 0.5243
# Epoch 6/20
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.3753 - acc: 0.5206 - val_loss: 1.3103 - val_acc: 0.5389
# Epoch 7/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.3469 - acc: 0.5301 - val_loss: 1.3102 - val_acc: 0.5446
# Epoch 8/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.3309 - acc: 0.5352 - val_loss: 1.3011 - val_acc: 0.5448
# Epoch 9/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.3219 - acc: 0.5435 - val_loss: 1.2823 - val_acc: 0.5546
# Epoch 10/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.2943 - acc: 0.5505 - val_loss: 1.2819 - val_acc: 0.5560
# Epoch 11/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.2788 - acc: 0.5596 - val_loss: 1.2411 - val_acc: 0.5669
# Epoch 12/20
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.2665 - acc: 0.5646 - val_loss: 1.2520 - val_acc: 0.5604
# Epoch 13/20
# 1563/1563 [==============================] - 29s 19ms/step - loss: 1.2718 - acc: 0.5632 - val_loss: 1.2352 - val_acc: 0.5756
# Epoch 14/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.2507 - acc: 0.5683 - val_loss: 1.2246 - val_acc: 0.5748
# Epoch 15/20
# 1563/1563 [==============================] - 30s 19ms/step - loss: 1.2371 - acc: 0.5691 - val_loss: 1.2728 - val_acc: 0.5616
# Epoch 16/20
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.2301 - acc: 0.5776 - val_loss: 1.1977 - val_acc: 0.5867
# Epoch 17/20
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.2113 - acc: 0.5830 - val_loss: 1.2038 - val_acc: 0.5832
# Epoch 18/20
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.2152 - acc: 0.5821 - val_loss: 1.1843 - val_acc: 0.5945
# Epoch 19/20
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.1996 - acc: 0.5885 - val_loss: 1.2009 - val_acc: 0.5806
# Epoch 20/20
# 1563/1563 [==============================] - 31s 20ms/step - loss: 1.1921 - acc: 0.5893 - val_loss: 1.1876 - val_acc: 0.5874

# %%
model.save('CNN_CIFAR.h5')

# %%
model = load_model('CNN_CIFAR.h5')

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.show()

# %%
predictions = model.predict(X_test)

# %%
predictions = one_hot_encoder.inverse_transform(predictions)

# %%
y_test = one_hot_encoder.inverse_transform(y_test)

# %%
cm = confusion_matrix(y_test, predictions)

# %%
plt.figure(figsize=(9,9))
sns.heatmap(cm, cbar=False, xticklabels=labels, yticklabels=labels, fmt='d', annot=True, cmap=plt.cm.Blues)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], X_test.shape[2])

# %%
y_test = y_test.astype(int)
predictions = predictions.astype(int)

# %%
fig, axes = plt.subplots(ncols=7, nrows=3, sharex=False,
    sharey=True, figsize=(17, 8))
index = 0
for i in range(3):
    for j in range(7):
        axes[i,j].set_title('actual:' + labels[y_test[index][0]] + '\n' 
                            + 'predicted:' + labels[predictions[index][0]])
        axes[i,j].imshow(X_test[index], cmap='gray')
        axes[i,j].get_xaxis().set_visible(False)
        axes[i,j].get_yaxis().set_visible(False)
        index += 1
plt.show()

# %%
#Classification accuracy
from sklearn.metrics import accuracy_score
acc_score = accuracy_score(y_test,predictions)
print('Testing Accuracy Score = ', acc_score)
# Out:
# Testing Accuracy Score =  0.5874

# %% [markdown]
# # In AlexNet i  have tried the same dataset which gives us the accuracy of 46.37% while when i applied the same dataset with this LeNet model we get testing accuracy as 58.74%.
#
# #Hence we can say LeNet performs better then AlexNet for this Cifar10 Dataset
